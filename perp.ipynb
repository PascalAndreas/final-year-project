# %%
# %load_ext autoreload
# %autoreload 2

import requests
import json
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from tqdm.auto import tqdm
import time
import matplotlib.pyplot as plt

from utils import (
    fetch_market_data, parse_future_name, bin_orderbook,
    compute_segment_carry, interpolate_forward, compute_continuous_forward_curve
)

# %%
start_date = datetime(2025, 8, 17)
end_date = start_date + timedelta(days=1)

# Fetch 1-minute candlestick data
candles = fetch_market_data(2, 'SWAP', 'BTC-USD', start_date, end_date, 'daily')

print(candles['instrument_name'].unique())
# Out:
# Fetching SWAP data (module=2) for BTC-USD
# Period: 2025-08-17 00:00:00 to 2025-08-18 00:00:00
# Split into 1 requests
# Fetching data:   0%|          | 0/1 [00:00<?, ?it/s]
# Fetch #1/1: 2 files found | Total: 2 files, 0.05 MB
# ...
# ✓ Successfully fetched 2880 records
# ['BTC-USD-SWAP']

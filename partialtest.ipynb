# %%
from okx.recipes import prepare_pillars
from functools import partial

pillars_partial = partial(prepare_pillars, drop_pillar_idx=0)

# %%
print(pillars_partial.func.__name__)

print(pillars_partial.keywords)
# Out:
# prepare_pillars
# {'drop_pillar_idx': 0}
